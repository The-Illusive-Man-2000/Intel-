# %%
from PIL import Image, ImageOps

# %%
image = Image.open('task1.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1620x452 at 0x2C78BC4E760>

# %%
def count_internal_nodes(test_tree):
    s = set(test_tree)
    s.discard(-1)
    return len(s)

# %%
tree = [1, 3, 1, -1, 3]
print(count_internal_nodes(tree))
# Out:
# 2
