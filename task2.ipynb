# %%
import json
from PIL import Image, ImageOps

# %%
image = Image.open('task2.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1620x607 at 0x2D8EAAF8C40>

# %%
def sort_by_price_ascending(json_string):
    s = json.loads(json_string)
    new_list = sorted(s, key=lambda k: (k['price'], k['name']))
    return str(new_list)

# %%
print(sort_by_price_ascending('[{"name":"eggs","price":1},{"name":"coffee","price":9.99},{"name":"rice","price":4.04}]'))
# Out:
# [{'name': 'eggs', 'price': 1}, {'name': 'rice', 'price': 4.04}, {'name': 'coffee', 'price': 9.99}]
